# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/DL-Training/blob/master/dcgan_color_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from matplotlib import pyplot as plt
import numpy as np

import os

# %% [markdown]
# Its always a good practice to check the current version of TensorFlow...

# %%
print(tf.version.VERSION)
# Out:
# 2.8.2

# %% [markdown]
# ## Data
#
# We will train the DCGAN on a dataset called [Clothing & Models](https://www.kaggle.com/dqmonn/zalando-store-crawl) from Kaggle, which is a collection of clothing pieces, scraped from Zalando.com.
#
# Here is how to download Kaggle data from Colab:
# * Navigate to https://www.kaggle.com.
# * Go to the [account tab](https://www.kaggle.com/me/account)  of your user profile.
# * Select "Create API Token" which triggers the download of kaggle.json, a file containing your API credentials.
# * Enter your username and Kaggle key in the cell below.

# %%
os.environ['KAGGLE_USERNAME']="mohanraj4072" 
os.environ['KAGGLE_KEY']="2f0e5f537058775b894b214de6604785"

# %%
# download kaggle dataset to 'datasets/' path
# !kaggle datasets download -d dqmonn/zalando-store-crawl -p datasets
# Out:
# Downloading zalando-store-crawl.zip to datasets
# 100% 2.24G/2.24G [00:19<00:00, 149MB/s]
# 100% 2.24G/2.24G [00:19<00:00, 122MB/s]

# %%
# !unzip datasets/zalando-store-crawl.zip -d datasets/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00K-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00L-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00L-H11@7.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00L-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00M-G11@13.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00N-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00O-Q11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00P-N11@5.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00Q-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00U-A11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NAA21J00V-P11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J007-Q11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00C-A11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00D-J11@2.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00D-Q11@2.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00D-Q12@2.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00E-A11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00E-C11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NE221J00E-Q11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J05P-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-A11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-G12@7.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-J13@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-J14@10.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J066-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J07U-Q11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J084-C11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J084-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J086-E11@8.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J086-G11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J086-H11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J086-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J086-N11@16.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J087-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J088-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J088-H11@14.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J088-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J088-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J088-Q11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J089-H11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08A-C11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08B-G11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08B-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08D-A11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08D-Q11@6.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08E-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08F-H11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08G-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08H-A11@16.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08H-C11@14.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08H-Q11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08I-C11@15.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08U-Q11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08W-C11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08W-N11@13.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08X-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08X-J11@4.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J08X-Q11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J090-C11@14.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J090-H11@9.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J090-Q11@14.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J092-A11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J092-J11@6.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J092-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J09Z-Q11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J0A2-A11@2.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NI121J0AF-B11@1.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04L-A11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04O-B11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04Q-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04R-E11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04T-B11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04T-E11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04T-H11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04U-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04V-H11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J04X-C11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J050-A11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J051-M11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J055-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J058-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J058-G11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NL021J05B-H11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03D-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03D-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03E-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03F-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03F-J11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03F-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03G-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03G-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03H-G11@8.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03H-M11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03I-G11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03I-J11@10.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03I-M11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03I-Q11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03J-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03L-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03L-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03N-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03N-G11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03N-H11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03N-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03N-M11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03O-C11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03O-K11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03P-C11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03S-G11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03S-K11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03T-K11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03U-A11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM321J03V-K11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM521J00B-C11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM521J00C-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NM521J00D-G11@13.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NN121J004-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NN121J005-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NOB21E00P-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NT521J002-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NU121J02B-G11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NU121J02D-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NU121J02E-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/NU121J02F-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021D011-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J002-N11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00T-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00U-O11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00V-M11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00X-Q11@6.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00Y-E11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J00Y-K11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J010-G11@5.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/OB021J012-K11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0ED-J11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0ED-K13@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0GS-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0GS-N11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0GS-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H0-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H0-M11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H1-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H1-C12@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H2-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H2-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H4-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H4-G11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H4-J11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H4-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H4-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H6-E11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H6-J11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H6-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H7-G11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H7-I11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H8-B11@17.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H8-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H9-K11@16.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0H9-Q11@16.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HA-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HC-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HC-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HC-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HD-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HD-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HE-C11@8.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HE-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HF-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HF-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HM-C11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HM-J11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HN-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HO-H11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HO-I11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HO-N11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HO-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HP-C11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HP-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HQ-C11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HQ-O11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HR-G11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HR-J11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HR-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HS-C11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HS-H11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HT-Q11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HY-C11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HY-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0HY-Q11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I3-I11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I3-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I3-M11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I3-Q11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I4-G11@4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0I4-K11@4.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt-female/ON321J0
@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00H-J11@8.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00I-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00J-M11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00N-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00V-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S00W-G11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S016-Q11@11.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/WR122S017-H11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-A11@17.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-C11@25.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-G11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-K12@19.2.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-N11@16.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S00R-Q11@30.2.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S02G-A11@18.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S02G-C11@18.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S02G-G11@10.4.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S02G-K11@16.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S02G-Q11@18.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S055-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05H-A11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05H-Q11@11.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05U-E11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05V-G11@16.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05W-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05X-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S05Y-C11@10.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S063-K11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S064-A11@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S064-Q11@15.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S065-Q11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S069-Q11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06A-C11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06D-A11@15.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06E-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06H-H11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06I-C11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06J-Q11@15.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06N-C11@9.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06N-K11@11.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06O-K11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06O-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06P-Q11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06R-C11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06S-K11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06X-K11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S06Z-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S070-Q11@21.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S071-C11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S073-A11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S075-H11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S076-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S077-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S078-Q11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S079-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07A-A11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07C-A11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07D-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07G-M11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07H-K11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07H-Q11@11.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07J-Q11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07K-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07L-M11@14.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07O-Q11@12.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07P-G11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07X-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07Y-Q11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S07Z-Q11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S081-C11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S082-Q11@13.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S095-A11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122S095-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA15-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA1F-C11@10.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA1F-Q11@9.2.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA38-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA38-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA43-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA44-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA46-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-A11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-G11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-G12@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-G13@12.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-H11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4S-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4V-A11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA4V-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA51-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA6I-J11@11.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA76-A11@9.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA7D-N11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA7D-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA8X-N11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9I-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9Q-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9U-A11@7.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9U-Q11@5.2.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9V-Q11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9X-E11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO122SA9X-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO422S007-K11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YO422S007-M11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G009-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G009-G11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G009-M11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G009-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00A-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00A-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00D-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00D-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00D-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00E-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00E-G11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00E-K11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00E-M11@10.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00E-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00F-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142G00F-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/YT142GA13-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/Z2122S003-Q11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/Z2122S004-B11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/Z2122S005-Q11@7.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S002-C11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S002-K11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S002-K12@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S002-Q11@10.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S004-C11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S005-C11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S005-K11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S005-N11@22.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S005-Q11@11.1.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/ZA822S006-N11@8.jpg
#   inflating: datasets/zalando/zalando/sweatshirt/sweatshirt.txt

# %%
zalando_data_dir = "/content/datasets/zalando/zalando"

# %%
train_images = tf.keras.utils.image_dataset_from_directory(
    zalando_data_dir, label_mode=None, image_size=(64, 64), batch_size=32
)
# Out:
# Found 16180 files belonging to 1 classes.

# %% [markdown]
# ### Visualization
#
# I always like to visualize the training data to get an idea of what the images look like.

# %%
image_batch = next(iter(train_images))
random_index = np.random.choice(image_batch.shape[0])
random_image = image_batch[random_index].numpy().astype("int32")
plt.axis("off")
plt.imshow(random_image)
plt.show()

# %% [markdown]
# ### Preprocessing

# %%
# Normalize the images to [-1, 1] which is the range of the tanh activation
train_images = train_images.map(lambda x: (x - 127.5) / 127.5)

# %% [markdown]
# ## The Generator
#
# Define the generator model architecture with the Keras `Sequential` API.
#
# Use `ReLU` except for the last layer which has `tanh` as the activation.
#
# The job of the generator is to make images, to do so in DCGAN, we feed random noise as input to the generator and upsample till the desired image size becomes 64x64x3.

# %%
# latent dimension of the random noise
LATENT_DIM = 100 
# weight initializer for G per DCGAN paper
WEIGHT_INIT = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.02) 
# number of channels, 1 for gray scale and 3 for color images
CHANNELS = 3 # UPDATED from 1

# %%
def build_generator():
    # create a Keras Sequential model 
    model = Sequential(name='generator')

    # prepare for reshape: FC => BN => RN layers, note: input shape defined in the 1st Dense layer  
    model.add(layers.Dense(8 * 8 * 512, input_dim=LATENT_DIM))
    # model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    # layers.LeakyReLU(alpha=0.2),

    # 1D => 3D: reshape the output of the previous layer 
    model.add(layers.Reshape((8, 8, 512)))

    # upsample to 16x16: apply a transposed CONV => BN => RELU
    model.add(layers.Conv2DTranspose(256, (4, 4), strides=(2, 2),padding="same", kernel_initializer=WEIGHT_INIT))
    # model.add(layers.BatchNormalization())
    model.add((layers.ReLU()))

    # upsample to 32x32: apply a transposed CONV => BN => RELU
    model.add(layers.Conv2DTranspose(128, (4, 4), strides=(2, 2),padding="same", kernel_initializer=WEIGHT_INIT))
    # model.add(layers.BatchNormalization())
    model.add((layers.ReLU()))

    # upsample to 64x64: apply a transposed CONV => BN => RELU
    model.add(layers.Conv2DTranspose(64, (4, 4), strides=(2, 2),padding="same", kernel_initializer=WEIGHT_INIT))
    # model.add(layers.BatchNormalization())
    model.add((layers.ReLU()))

    # final layer: Conv2D with tanh activation
    model.add(layers.Conv2D(CHANNELS, (4, 4), padding="same", activation="tanh"))

    # return the generator model
    return model

# %%
# build the generator model
generator = build_generator()

# %%
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32768)             3309568
#
#  re_lu (ReLU)                (None, 32768)             0
#
#  reshape (Reshape)           (None, 8, 8, 512)         0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 256)      2097408
#  nspose)
#
#  re_lu_1 (ReLU)              (None, 16, 16, 256)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 128)      524416
#  ranspose)
#
#  re_lu_2 (ReLU)              (None, 32, 32, 128)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 64)       131136
#  ranspose)
#
#  re_lu_3 (ReLU)              (None, 64, 64, 64)        0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         3075
#
# =================================================================
# Total params: 6,065,603
# Trainable params: 6,065,603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## The Discriminator
#
# Define the discriminator model architecture with the Keras `Sequential` API

# %%
def build_discriminator(height, width, depth, alpha=0.2):
    # create a Keras Sequential model
    model = Sequential(name='discriminator')
    input_shape = (height, width, depth)

    # 1. first set of CONV => BN => leaky ReLU layers
    model.add(layers.Conv2D(64, (4, 4), padding="same", strides=(2, 2),
        input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=alpha))

    # 2. second set of CONV => BN => leacy ReLU layers
    model.add(layers.Conv2D(128, (4, 4), padding="same", strides=(2, 2)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=alpha))

    # 3. third set of CONV => BN => leacy ReLU layers
    model.add(layers.Conv2D(128, (4, 4), padding="same", strides=(2, 2)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=alpha))

    # flatten and apply dropout
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.3))

    # sigmoid in the last layer outputting a single value for binary classification
    model.add(layers.Dense(1, activation="sigmoid"))

    # return the discriminator model
    return model

# %%
# build the discriminator model
discriminator = build_discriminator(64, 64, 3)

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        3136
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       131200
#
#  batch_normalization_1 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         262272
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense_1 (Dense)             (None, 1)                 8193
#
# =================================================================
# Total params: 406,081
# Trainable params: 405,441
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ## DCGAN

# %% [markdown]
# ### Define the DCGAN class
# Subclass `keras.Model` and override `train_step()` to implement the DCGAN architecture. This is where the magic happens and the heart of the DCGAN implementation. [TODO: explain minimax objective function in tutorial, along with visual illustrations]

# %%
class DCGAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(DCGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):

        batch_size = tf.shape(real_images)[0]
        noise = tf.random.normal(shape=(batch_size, self.latent_dim))

        # Step 1. Train the discriminator with both real images (label as 1) and fake images (classified as label as 0) 
        with tf.GradientTape() as tape:
            # Compute discriminator loss on real images
            pred_real = self.discriminator(real_images, training=True)
            real_labels = tf.ones((batch_size, 1))
            # UPDATED: apply one-sided label smoothing to real labels
            real_labels += 0.05 * tf.random.uniform(tf.shape(real_labels)) 
            d_loss_real = self.loss_fn(real_labels, pred_real)

            # Compute discriminator loss on fake images
            fake_images = self.generator(noise)
            pred_fake = self.discriminator(fake_images, training=True)
            fake_labels = tf.zeros((batch_size, 1))
            # UPDATED: add random noise to fake labels - not needed
            # fake_labels += 0.05 * tf.random.uniform(tf.shape(fake_labels)) 
            d_loss_fake = self.loss_fn(fake_labels, pred_fake)

            # total discriminator loss
            d_loss = (d_loss_real + d_loss_fake)/2
        # Compute discriminator gradients
        grads = tape.gradient(d_loss, self.discriminator.trainable_variables)
        # Update discriminator weights
        self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_variables))

        # Step 2. Train the generator (do not update weights of the discriminator)
        misleading_labels = tf.ones((batch_size, 1)) # G wants D to think the fake images are real (label as 1)

        with tf.GradientTape() as tape:
            fake_images = self.generator(noise, training=True)
            pred_fake = self.discriminator(fake_images, training=True)
            g_loss = self.loss_fn(misleading_labels, pred_fake)
        # Compute generator gradients
        grads = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update generator wieghts
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_variables))

        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {"d_loss": self.d_loss_metric.result(), "g_loss": self.g_loss_metric.result()}

# %% [markdown]
# ### Use Keras Callback to monitor training

# %% [markdown]
# The nice thing about overriding `train_step()` of `keras.Model()` is that we can subclass `Callback` to monitor our DCGAN training.
#
# I use the seed noise to create images (with the generator model) throughout the training to see the progress of the generator is making. Also saved the generator model at the end of the training which could potentially be used for inference later.

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=100):
        self.num_img = num_img
        self.latent_dim = latent_dim

        # Create random noise seed for visualization during traing
        self.seed = tf.random.normal([16, latent_dim])

    def on_epoch_end(self, epoch, logs=None):
        generated_images = self.model.generator(self.seed)
        generated_images = (generated_images * 127.5) + 127.5
        generated_images.numpy()

        fig = plt.figure(figsize=(4, 4))
        for i in range(self.num_img):
            plt.subplot(4, 4, i+1)
            img = keras.utils.array_to_img(generated_images[i]) 
            plt.imshow(img)
            plt.axis('off')
        plt.savefig('epoch_{:03d}.png'.format(epoch)) 
        plt.show()

    def on_train_end(self, logs=None):
        self.model.generator.save('generator.h5')

# %% [markdown]
# ### The DCGAN model - putting it together

# %%
dcgan = DCGAN(discriminator=discriminator, generator=generator, latent_dim=LATENT_DIM)

# %% [markdown]
# ## Compile DCGAN
#
# Compile the dcgan model, use the `Adam` optimizer, learning rate of 0.0002, and the **Binary Cross Entropy** as recommended by the paper.
#
# In later GAN tutorials, you will learn that we can use other loss functions for other GAN variants.

# %%
D_LR = 0.0001 # UPDATED: discriminator learning rate
G_LR = 0.0003 # UPDATED: generator learning rate

dcgan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=D_LR, beta_1 = 0.5),
    g_optimizer=keras.optimizers.Adam(learning_rate=G_LR, beta_1 = 0.5),  
    loss_fn=keras.losses.BinaryCrossentropy(),
)

# %% [markdown]
# ## Train DCGAN
# Now we simply call `model.fit()` to traing the dcgan model!

# %%
NUM_EPOCHS = 50 # number of epochs
dcgan.fit(train_images, epochs=NUM_EPOCHS, callbacks=[GANMonitor(num_img=16, latent_dim=LATENT_DIM)])
# Out:
# Epoch 1/50
# 506/506 [==============================] - ETA: 0s - d_loss: 0.6293 - g_loss: 2.8470
# 506/506 [==============================] - 94s 152ms/step - d_loss: 0.6293 - g_loss: 2.8470
# Epoch 2/50
#  81/506 [===>..........................] - ETA: 1:02 - d_loss: 0.6044 - g_loss: 3.3590
